# %% [markdown]
# # La piramide di Chichen Itza
#
# La piramide Maya di Chichen-Itza, in Messico, è famosa per un curioso fenomeno: si dice	che battendo le mani di fronte alla sua grande scalinata, sarà possibile ottenere risposta	dall'uccello sacro dei Maya, il Quetzal.

# %% [markdown]
# ![el-castillo.jpg](attachment:d28fe215-6ae2-4859-b26a-4917010cd2f1.jpg)

# %% [markdown]
# La spiegazione completa di questo fenomeno richiederebbe un po' di lavoro, ma possiamo provare a produrre un modello semplificato.
#
# Schematizziamo la situazione immaginando una persona (per noi rappresentata da un punto A) situata alla base di una scalinata.

# %% [markdown]
# ![maya.png](attachment:8bd8a3a4-b0c3-41a7-a40c-bfc53864de44.png)

# %% [markdown]
# Quando $A$ batte le mani, il suono viene riflesso sui vari gradini, e torna indietro. Ogni gradino si trova però ad una distanza diversa da $A$, e dunque il suono impiegherà un tempo diverso a tornare indietro, traducendosi in una sequenza di echi lievemente sfasati, in numero uguale al numero	di gradini.
#
# Si provi a simulare l'eco udito da $A$ considerando come distanza dalla base della piramide $10$ metri, e supponendo che la piramide sia composta da $150$ gradini, ciascuno di altezza e profondità pari a $20$ centimetri. Si consideri come velocità del suono $340$ metri al secondo, determinando il tempo necessario	ad ogni eco per tornare ad $A$.
#
# Si provi ad applicare questo effetto di eco al suono ottenuto leggendo il file ```handclap.wav```. Si imponga un attenuamento al suono di ritorno, senza tener conto della distanza.

# %%
from settimanamatematica import *
# Carichiamo un suono, ad esempio il battito di mani, e proviamo a simulare l'eco della piramide

# %% [markdown]
# Notiamo che il nostro modello non è estremamente raffinato; per simulare davvero il suono	prodotto dalla piramide bisognerebbe tenere conto del fatto che i gradini più alti riflettono	solo le basse frequenze, mentre quelli più bassi le alte frequenze. Tuttavia, questo primo esperimento è sufficiente per produrre degli effetti interessanti.
